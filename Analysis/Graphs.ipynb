# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from scipy.stats import linregress
from pprint import pprint

# %%
cities_pd = pd.read_csv("../data/emission_population_data.csv", encoding="ISO-8859-1" )

cities_pd.head()
# Out:
#                  City_State         City State  population2010  \
# 0  New York City , New York     New York    NY         8175133
# 1  Los Angeles , California  Los Angeles    CA         3792621
# 2        Chicago , Illinois      Chicago    IL         2695598
# 3           Houston , Texas      Houston    TX         2099451
# 4         Phoenix , Arizona      Phoenix    AZ         1445632
#
#    population2011  population2012  population2013  population2014  \
# 0         8272948         8346693         8396091         8433806
# 1         3820876         3851202         3881622         3909901
# 2         2708114         2719141         2725731         2727066
# 3         2126032         2161593         2199391         2241826
# 4         1469796         1499274         1526491         1555445
#
#    population2015  population2016  population2017  emissions2010  \
# 0         8463049         8469153         8437478   1.145691e+10
# ...

# %%
cities_emissions = cities_pd[["City", "emissions2010", "emissions2011", "emissions2012", "emissions2013", "emissions2014", "emissions2015", "emissions2016", "emissions2017"]]
cities_emissions = cities_emissions.rename(columns = {'emissions2010':'2010', 'emissions2011':"2011",'emissions2012':"2012", 'emissions2013':"2013", 'emissions2014':"2014",'emissions2015':"2015", 'emissions2016':"2016", 'emissions2017':"2017" })
cities_emissions
# Out:
#            City          2010          2011          2012          2013  \
# 0      New York  1.145691e+10  1.025721e+10  9.592850e+09  9.491282e+09
# 1   Los Angeles  1.633195e+10  1.497791e+10  1.413437e+10  1.361190e+10
# 2       Chicago  6.498994e+09  6.246525e+09  6.146778e+09  6.242132e+09
# 3       Houston  2.037585e+10  1.971698e+10  1.948527e+10  1.957627e+10
# 4       Phoenix  7.802805e+09  7.772033e+09  7.589138e+09  7.396678e+09
# ..          ...           ...           ...           ...           ...
# 93      Hialeah  1.074061e+09  1.048081e+09  1.030512e+09  1.010589e+09
# 94     Richmond  1.342048e+09  1.270741e+09  1.250544e+09  1.241224e+09
# 95        Boise  1.308069e+09  1.300467e+09  1.266602e+09  1.226029e+09
# 96      Spokane  8.916472e+08  8.900212e+08  8.975698e+08  8.838752e+08
# 97  Baton Rouge  1.885289e+09  1.819968e+09  1.709733e+09  1.687416e+09
#
#             2014          2015          2016          2017
# ...

# %%
cities_emissions.loc[cities_emission[plot(kind="line")
